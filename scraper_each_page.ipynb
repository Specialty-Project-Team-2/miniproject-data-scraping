# %%
from util.scraper import scrap

from selenium.webdriver.chrome.webdriver import WebDriver

from util.file_handler import load_file_line_by_line, create_directory_if_not_exists, make_file_path
from util.driver_util import save_html_as

# %%
url_generator = load_file_line_by_line("wanted_scraping_url.txt")

# %%
# 페이지 저장을 위한 디렉토리 생성.
ROOT_DIR = "wanted"

create_directory_if_not_exists(make_file_path(ROOT_DIR))

# %%
def extract_id_from_url(url : str):
    return url.rpartition("/")[-1]

# %%
def execute_plan_unit(driver : WebDriver, url : str):
    driver.get(url)
    
    id = extract_id_from_url(url)
    save_html_as(driver, file_name=f"{ROOT_DIR}/{id}.html")

# %%
def execute_plan(driver : WebDriver):
    for url in url_generator:
        execute_plan_unit(driver, url)

# %%
scrap(execute_plan)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\wjdgn\PythonWorkSpace\miniproject-data-scraping\scraper_each_page.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/wjdgn/PythonWorkSpace/miniproject-data-scraping/scraper_each_page.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> scrap(execute_plan)
#
# File c:\Users\wjdgn\PythonWorkSpace\miniproject-data-scraping\util\scraper.py:11, in scrap(execute_plan)
#       9 def scrap(execute_plan : Callable[[WebDriver], None]) -> None:
#      10     with webdriver.Chrome(service=service, options=options) as driver:
# ---> 11         execute_plan(driver)
#
# c:\Users\wjdgn\PythonWorkSpace\miniproject-data-scraping\scraper_each_page.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/wjdgn/PythonWorkSpace/miniproject-data-scraping/scraper_each_page.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> def execute_plan(driver : WebDriver):
#       <a href='vscode-notebook-cell:/c%3A/Users/wjdgn/PythonWorkSpace/miniproject-data-scraping/scraper_each_page.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a>     for url in url_generator:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/wjdgn/PythonWorkSpace/miniproject-data-scraping/scraper_each_page.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>         execute_plan_unit(driver, url)
#
# c:\Users\wjdgn\PythonWorkSpace\miniproject-data-scraping\scraper_each_page.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/wjdgn/PythonWorkSpace/miniproject-data-scraping/scraper_each_page.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> def execute_plan_unit(driver : WebDriver, url : str):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/wjdgn/PythonWorkSpace/miniproject-data-scraping/scraper_each_page.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a>     driver.get(url)
#       <a href='vscode-notebook-cell:/c%3A/Users/wjdgn/PythonWorkSpace/miniproject-data-scraping/scraper_each_page.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>     id = extract_id_from_url(url)
#       <a href='vscode-notebook-cell:/c%3A/Users/wjdgn/PythonWorkSpace/miniproject-data-scraping/scraper_each_page.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a>     save_html_as(driver, file_name=f"{ROOT_DIR}/{id}.html")
#
# File c:\Users\wjdgn\PythonWorkSpace\miniproject-data-scraping\.venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:353, in WebDriver.get(self, url)
#     351 def get(self, url: str) -> None:
#     352     """Loads a web page in the current browser session."""
# --> 353     self.execute(Command.GET, {"url": url})
#
# File c:\Users\wjdgn\PythonWorkSpace\miniproject-data-scraping\.venv\lib\site-packages\selenium\webdriver\remote\webdriver.py:342, in WebDriver.execute(self, driver_command, params)
#     339     elif "sessionId" not in params:
#     340         params["sessionId"] = self.session_id
# --> 342 response = self.command_executor.execute(driver_command, params)
#     343 if response:
#     344     self.error_handler.check_response(response)
#
# File c:\Users\wjdgn\PythonWorkSpace\miniproject-data-scraping\.venv\lib\site-packages\selenium\webdriver\remote\remote_connection.py:294, in RemoteConnection.execute(self, command, params)
#     292 data = utils.dump_json(params)
#     293 url = f"{self._url}{path}"
# --> 294 return self._request(command_info[0], url, body=data)
#
# File c:\Users\wjdgn\PythonWorkSpace\miniproject-data-scraping\.venv\lib\site-packages\selenium\webdriver\remote\remote_connection.py:315, in RemoteConnection._request(self, method, url, body)
#     312     body = None
#     314 if self.keep_alive:
# --> 315     response = self._conn.request(method, url, body=body, headers=headers)
#     316     statuscode = response.status
#     317 else:
#
# File c:\Users\wjdgn\PythonWorkSpace\miniproject-data-scraping\.venv\lib\site-packages\urllib3\_request_methods.py:118, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     110     return self.request_encode_url(
#     111         method,
#     112         url,
#    (...)
#     115         **urlopen_kw,
#     116     )
#     117 else:
# --> 118     return self.request_encode_body(
#     119         method, url, fields=fields, headers=headers, **urlopen_kw
#     120     )
#
# File c:\Users\wjdgn\PythonWorkSpace\miniproject-data-scraping\.venv\lib\site-packages\urllib3\_request_methods.py:217, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     213     extra_kw["headers"].setdefault("Content-Type", content_type)
#     215 extra_kw.update(urlopen_kw)
# --> 217 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\wjdgn\PythonWorkSpace\miniproject-data-scraping\.venv\lib\site-packages\urllib3\poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File c:\Users\wjdgn\PythonWorkSpace\miniproject-data-scraping\.venv\lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File c:\Users\wjdgn\PythonWorkSpace\miniproject-data-scraping\.venv\lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\wjdgn\PythonWorkSpace\miniproject-data-scraping\.venv\lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\http\client.py:1344, in HTTPConnection.getresponse(self)
#    1342 try:
#    1343     try:
# -> 1344         response.begin()
#    1345     except ConnectionError:
#    1346         self.close()
#
# File ~\AppData\Local\Programs\Python\Python38\lib\http\client.py:307, in HTTPResponse.begin(self)
#     305 # read until we get a non-100 response
#     306 while True:
# --> 307     version, status, reason = self._read_status()
#     308     if status != CONTINUE:
#     309         break
#
# File ~\AppData\Local\Programs\Python\Python38\lib\http\client.py:268, in HTTPResponse._read_status(self)
#     267 def _read_status(self):
# --> 268     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269     if len(line) > _MAXLINE:
#     270         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python38\lib\socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# KeyboardInterrupt:
